# %%
class bank_account(object):
    def __init__(self):
        self.account_number=""
        self.name=""
        self.balance=0
        self.pincode=""
    
    
    def setaccount_number(self,a):
        self.account_number=a
    def getaccount_number(self):
        return self.account_number
    
    
    def setname(self,n):
        self.name=n
    def getname(self):
        return self.name
    
    
    def setbalance(self,b):
        self.balance=b
    def getbalance(self):
        return self.balance
        
    def setpincode(self,p):
        self.pincode=p
    def getpincode(self):
        return self.pincode
    
        
                

            
            
    def deposit(self,number,enter_pin,amount):
        number=int(input("Enter account number: "))
        if number == self.account_number:
            print("\n your account number is =",number)
        else:
            print("your account number is incoorect")
        enter_pin=int(input("enter your pin code"))
        if enter_pin == self.pincode:
            amount=int(input("enter deposit amount:"))
        else:
            print("incorrect pin")
        total=amount+self.balance
        print("your total amount is:",total)   
            
      
    
    def withdrow(self,number,enter_pin,amount):
        number=int(input("Enter account number: "))
        if number == self.account_number:
            print("\n your account number is =",number)
        else:
            print("your account number is incoorect")
        enter_pin=int(input("enter your pin code"))
        if enter_pin == self.pincode:
            amount=int(input("enter deposit amount:"))
        else:
            print("incorrect pin")
        total=amount-self.balance
        print("your total amount is:",total)
        
        
        
                      
    def display(self,account_number,pincode):
        account_number=int(input("enter account number:"))
        if account_number==self.account_number:
            pincode=int(input("enter your pin code:"))
        else:
            print("account number is incoorect")
        pincode=int(input("enter your pin code:"))       
        if pincode==self.pincode:
            print(self.account_number)
            print(self.name)
            print(self.balance)
        else:
            print("your pin code is incorrect")

# %%
a=[]
while(1):
    print("press 1 for create account:")
    print("press 2 for create account:")
    print("press 3 for create account:")
    print("press 4 for create account:")
    print("press 5 for create account:")
    print("press 6 to exit:")
    i=int(input())
    if (i==1):
        b=bank_account()
        name=input("enter your name:")
        account_number=int(input("enter account number:"))
        pincode=int(input("enter your pin code:"))
        balance=(input("enter your balance:"))
        b.setname(name)
        b.setaccount_number(account_number)
        b.setpincode(pincode)
        b.setbalance(balance)
        a.append(b)
        print("account crated successully")
    elif i==2:
        account_number=input("enter your account number to remove :")
        pin=input("enter your pin code:")
        for account in a:
            if (account.getaccount_number==account_number and account.getpincode==pincode):
                a.remove(account)
                print("your account was remove")
            else:
                print("incorrect")
            
    
    
    
    
    
    else:
        break;
# Out:
# press 1 for create account:
# press 2 for create account:
# press 3 for create account:
# press 4 for create account:
# press 5 for create account:
# press 6 to exit:
# 1
# enter your name:khan
# enter account number:1111
# enter your pin code:111
# enter your balance:11
# account crated successully
# press 1 for create account:
# press 2 for create account:
# press 3 for create account:
# press 4 for create account:
# press 5 for create account:
# press 6 to exit:
